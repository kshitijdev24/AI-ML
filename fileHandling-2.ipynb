# %% [markdown]
# <a href="https://colab.research.google.com/github/kshitijdev24/AI-ML/blob/main/fileHandling-2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
with open("/code.txt","r") as file:
  print(file.tell())
  print(file.read(4))
  print(file.tell())
  print(file.read(4))
# Out:
# 0
# DATA
# 4
#  SCI

# %%
with open("/orders.txt","r") as file:
  for line in file:
    item,qty=line.strip().split(",")
    print("Item :",item," |Quantity: ",qty)
# Out:
# Item : Tea  |Quantity:  4
# Item : Cookies  |Quantity:  2
# Item : Juice  |Quantity:  5

# %%
import os
if os.path.exists("/old_report.txt"):
  os.remove("/old_report.txt")
  print("removed")
else:
  print("File not found")
# Out:
# removed
